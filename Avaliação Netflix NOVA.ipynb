# %% [markdown]
# ### A partir dos 4 filmes mais bem avaliados pelos usuários do Netflix, qual será a nota que um desses 4 filmes tem, sabendo as notas dos outros 3?

# %% [markdown]
# ### link para pegar os dados: https://www.kaggle.com/netflix-inc/netflix-prize-data/data

# %% [markdown]
# #### A partir dos dados que tinhamos, e conversando com os professores, decidimos pegar as notas dos 4 filmes mais bem avaliados a partir do site IMDb. Sabendo que esses filmes têm que estar no catálogo de filmes do Netflix.

# %% [markdown]
# ### FILMES:
# #### 1º Um Sonho de Liberdade
# #### 2º O Poderoso Chefão
# #### 3º O Poderoso Chefão parte 2
# #### 4º Pulp Fiction

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
lista_df  = []
 
with open ("movie_titles.csv") as f:
    for linha in f:
        lista_0 = []
        lista_1 = []
        lista_2 = [] 
        partes = linha.strip().split(",")
        juntando = ",".join(partes[2:])
        lista_0.append(partes[0])
        lista_1.append(partes[1])
        lista_2.append(juntando)
       
        #df.append({'classificacao' : lista_0, 'ano': lista_1, 'nome': lista_2}, ignore_index=True)
        temp = pd.DataFrame.from_dict({'Movie ID' : [partes[0]], 'Ano': [partes[1]], 'NOme': [juntando]})
        lista_df.append(temp)
 
dados = pd.concat(lista_df, ignore_index=True)

# %%
arquivo4 = open("combined_data_4.txt", "r")

# %%
tudo = arquivo4.readlines()

# %%
tudojunto = "\n".join(tudo)

# %%
for l in tudo:
    if "14550:" in l:
        print(l)
# Out:
# 14550:

# %%
partes = tudojunto.split("14550:")

# %%
len(partes[1])
# Out:
# 423565628

# %%
depois = partes[1]

# %%
partes_dep = depois.split("14551:")

# %%
partes_dep[0]
# Out:
# '\n\n736544,5,2005-07-05\n\n185150,5,2005-07-05\n\n2152963,4,2005-07-06\n\n1026389,5,2005-07-06\n\n1943087,5,2005-08-31\n\n364518,4,2004-10-05\n\n1392773,5,2004-10-05\n\n716091,5,2004-10-05\n\n2059652,4,2004-10-05\n\n2460625,5,2005-07-07\n\n1822148,5,2005-07-07\n\n1432761,5,2005-07-07\n\n923490,4,2005-07-08\n\n712664,4,2004-10-05\n\n1990901,5,2004-10-05\n\n757109,5,2005-07-08\n\n51762,5,2005-07-08\n\n1907667,4,2004-12-28\n\n554875,5,2004-10-05\n\n1437310,4,2005-07-09\n\n771345,4,2004-10-05\n\n669192,5,2005-07-10\n\n69867,5,2004-10-05\n\n2366565,5,2005-07-11\n\n1402412,5,2004-10-05\n\n1601783,4,2004-10-05\n\n1993470,5,2005-07-11\n\n2640108,4,2005-07-11\n\n306466,4,2004-10-05\n\n1278813,4,2004-10-05\n\n1216217,5,2004-10-05\n\n2560405,5,2005-07-12\n\n2385622,5,2005-07-12\n\n217982,4,2005-07-12\n\n1024794,5,2004-10-05\n\n2439005,5,2004-10-05\n\n477388,5,2004-10-05\n\n1331154,5,2004-10-05\n\n765331,3,2004-10-05\n\n1513370,5,2005-07-13\n\n1987434,5,2005-07-14\n\n2480084,5,2004-10-05\n\n175214,5,2005-07-15\n\n1567328,5,2004-10-05\n\n1165450,4,2004-10-05\n\n120539,5,
206156,5,2004-10-15\n\n1607938,4,2004-10-15\n\n2505267,4,2004-10-15\n\n66263,5,2005-08-06\n\n2569320,4,2004-10-15\n\n2173336,5,2005-08-07\n\n2266381,5,2005-08-07\n\n1850680,5,2005-08-07\n\n2457291,5,2004-10-15\n\n846887,4,2004-10-15\n\n1989800,4,2005-08-07\n\n1507374,5,2005-08-08\n\n2314362,4,2004-10-15\n\n787885,5,2005-08-08\n\n1730746,5,2005-08-09\n\n1519388,5,2005-08-09\n\n1635484,5,2004-10-15\n\n492722,5,2004-10-15\n\n179159,5,2005-08-10\n\n1767412,5,2004-10-15\n\n907840,5,2004-10-15\n\n656399,5,2004-10-15\n\n801646,3,2005-08-11\n\n1526264,5,2005-08-11\n\n1549706,4,2005-08-11\n\n1880037,5,2 ...

# %%
saida = open("depois_14550.txt", "w")

# %%
saida.write(partes_dep[0])
# Out:
# 3013732

# %%
#CRIANDO O ARQUIVO DO 3º LUGAR

# %%
arquivo1 = open("combined_data_1.txt", "r")

# %%
tudo3 = arquivo1.readlines()

# %%
tudojunto3 = "\n".join(tudo3)

# %%
for p in tudo3:
    if "3290:" in p:
        print(p)
# Out:
# 3290:

# %%
partes3 = tudojunto3.split("3290:")

# %%
len(partes3[1])
# Out:
# 151307311

# %%
depois3 = partes3[1]

# %%
partes_dep3 = depois3.split("3291:")

# %%
saida3 = open("depois_3290.txt", "w")

# %%
saida3.write(partes_dep3[0])
# Out:
# 1545185

# %%
#CRIANDO O ARQUIVO DO 2º LUGAR

# %%
arquivo3 = open("combined_data_3.txt", "r")

# %%
tudo2 = arquivo3.readlines()

# %%
tudojunto2 = "\n".join(tudo2)

# %%
for q in tudo2:
    if "12293:" in q:
        print(q)
# Out:
# 12293:

# %%
partes2 = tudojunto2.split("12293:")

# %%
len(partes2[1])

# %%
depois2 = partes2[1]

# %%
partes_dep2 = depois2.split("12294:")

# %%
saida2 = open("depois_12293.txt", "w")

# %%
saida2.write(partes_dep2[0])
# Out:
# 2294264

# %%
#CRIANDO O ARQUIVO DO 4º LUGAR

# %%
arquivo3_2 = open("combined_data_3.txt", "r")

# %%
tudo4 = arquivo3_2.readlines()

# %%
tudojunto4 = "\n".join(tudo4)

# %%
for f in tudo4:
    if "11064:" in f:
        print(f)
# Out:
# 11064:

# %%
partes4 = tudojunto4.split("11064:")

# %%
len(partes4[1])
# Out:
# 289794410

# %%
depois4 = partes4[1]

# %%
partes_dep4 = depois4.split("11065:")

# %%
saida4 = open("depois_11064.txt", "w")

# %%
saida4.write(partes_dep4[0])
# Out:
# 3281499

# %%
lugar1 = pd.read_csv('depois_14550.txt',sep=',')

# %%
lugar2 = pd.read_csv('depois_12293.txt',sep=',')

# %%
lugar3 = pd.read_csv('depois_3290.txt',sep=',')

# %%
lugar4 = pd.read_csv('depois_11064.txt',sep=',')

# %%
lugar1
# Out:
#          736544  5  2005-07-05
# 0        185150  5  2005-07-05
# 1       2152963  4  2005-07-06
# 2       1026389  5  2005-07-06
# 3       1943087  5  2005-08-31
# 4        364518  4  2004-10-05
# 71610  2512003  5  2005-12-23
# 71611  1316847  5  2005-12-24
# 71612  2350635  5  2005-12-27
#
# [71613 rows x 3 columns]

# %%
lugar4
# Out:
#         1026389  3  2005-07-06
# 0       1609049  4  2001-01-26
# 1       1342774  5  2000-02-03
# 2       1943087  5  2001-10-19
# 3       2423875  4  2000-01-12
# 4       1734805  5  2000-06-10
# 5       1392773  4  2000-05-17
# 6        716091  5  2000-01-08
# 7       1527030  4  2005-07-07
# 8        205706  4  2000-02-21
# 9       1744873  4  2005-07-07
# 10      1025579  5  2000-05-01
# 11       712664  5  2000-05-13
# 12      1990901  4  2000-04-15
# 13       857992  2  2005-07-08
# 14       179159  5  2005-07-08
# 15      1907667  4  2001-03-31
# 16       554875  5  2000-01-09
# 17      1994210  1  2005-07-09
# 18      1437310  4  2005-07-09
# 19       618502  1  2005-07-10
# 20        69867  3  2000-08-22
# 21      2366565  3  2005-07-11
# 22       913020  4  2005-07-11
# 23      1402412  3  2000-01-07
# 24      1601783  2  2000-01-15
# 25       719234  4  2000-02-23
# 26      1993470  5  2005-07-11
# 27       306466  5  2000-01-24
# 28       536721  4  2004-11-26
# 29      1278813  3  2000-03-07
# ...         ... ..         ...
# 152047    87898  5  2005-11-03
# 152048  2510785  2  2005-11-05
# 152049   109387  1  2005-11-06
# 152050  2369921  3  2005-11-08
# 152051   246103  4  2005-11-08
# 152052  1005618  4  2005-11-08
# 152053   271018  5  2005-11-09
# 152054   689486  3  2005-11-10
# 152055  1670169  5  2005-11-10
# 152056   833254  5  2005-11-11
# 152057   293198  4  2005-11-13
# 152058  1704768  5  2005-11-16
# 152059   676036  4  2005-11-16
# 152060   603885  4  2005-11-16
# 152061   543339  2  2005-11-21
# 152062  1289135  1  2005-11-29
# 152063  2300424  5  2005-11-30
# 152064   698715  5  2005-12-03
# 152065  2186425  3  2005-12-05
# 152066    17489  3  2005-12-13
# 152067  2486011  3  2005-12-14
# 152068  1510468  5  2005-12-17
# 152069   158902  4  2005-12-18
# 152070  1822872  5  2005-12-20
# 152071  1462398  4  2005-12-22
# 152072   252676  3  2005-12-23
# 152073  2512003  5  2005-12-23
# 152074  2310454  5  2005-12-25
# 152075   563965  5  2005-12-26
# 152076  2350635  2  2005-12-27
#
# [152077 rows x 3 columns]

# %%
dados

# %%
with open ("movie_titles.csv") as q:
    for linha in q:
        filmes = ["14550", "12293", "3290", "11064"]
        if linha [0:-1] in filmes:
            print (linha)

# %%
### AVALIAÇÕES DOS FILMES

sonho = 9,2
chefao = 9,2
chefao2 = 9
fiction = 8,9

# %%
#import numpy as np
#dic = {}
#avaliacoes = {}
#with open ("combined_data_1.txt") as f:
 #   for linha in f:
#      aval = []
#        if ":" in linha:
#            filme  = linha[:-1]
#            dic[filme]=[]
#        else:
#            aval.append(float(linha.split(",")[1]))
#            #dic[filme].append(float(linha.split(",")[1]))
#        media = np.mean(aval)
#        avaliacoes[filme] = media

# %% [markdown]
# ##### A partir da regressão linear, que estima um valor y (a nota de um filme) a partir de alguns valores x (as notas dos outros 3 filmes) obtivemos que.....
